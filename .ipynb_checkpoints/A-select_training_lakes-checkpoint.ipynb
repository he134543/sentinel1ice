# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# We select the same training lakes as the SLIDE algorithm does https://ieeexplore.ieee.org/document/9462830

# %%
slide_training_data = pd.read_csv("/mnt/Data_2tb/sentinel1_ice/training data.csv")

# %%
lake_ids = slide_training_data.Hylak_id.unique()
len(lake_ids)
# Out:
# 1360

# %% [markdown]
# # Export polygons of these lakes

# %%
hydrolakes = gpd.read_file("/mnt/Data_2tb/HydroSHEDS/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp")
hydrolakes
# Out:
#          Hylak_id    Lake_name                   Country      Continent  \
# 0               1  Caspian Sea                    Russia         Europe
# 1               2   Great Bear                    Canada  North America
# 2               3  Great Slave                    Canada  North America
# 3               4     Winnipeg                    Canada  North America
# 4               5     Superior  United States of America  North America
# ...           ...          ...                       ...            ...
# 1427683   1427684          NaN               New Zealand        Oceania
# 1427684   1427685          NaN                 Australia        Oceania
# 1427685   1427686          NaN                 Australia        Oceania
# 1427686   1427687          NaN                 Australia        Oceania
# 1427687   1427688          NaN                 Australia        Oceania
#
#         Poly_src  Lake_type  Grand_id  Lake_area  Shore_len  Shore_dev  ...  \
# ...

# %%
training_lakes = hydrolakes.loc[hydrolakes.Hylak_id.isin(lake_ids)]

# %%
training_lakes.to_file("/mnt/Data_2tb/sentinel1_ice/lake_polys/traing_lakes_s1_s2.shp")

# %%
training_lakes.set_index("Hylak_id").to_csv("data/training_lakes.csv")
